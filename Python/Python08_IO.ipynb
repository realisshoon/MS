# %%
#IO (Input/Output)

print(1)
# Out:
# 1

# %%
import sys
print('Welcome to ',' Python',sep='~',end='!',file=sys.stderr)
# Out:
# Welcome to ~ Python!

# %%
f=open('test.txt','w')

# %%
print('Welcome to python',file=f)

# %%
f.close() #file 닫고 열어야 깨짐현상이 생길 확률이 줄어듦

# %%
f=open('test.txt','r')

# %%
f.read() #한줄씩 읽어옴
# Out:
# 'Welcome to python\n'

# %%
f.read()
# Out:
# ''

# %%
f.readline()
# Out:
# 'Welcome to python\n'
