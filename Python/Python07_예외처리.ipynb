# %%
#예외처리

a=[10,20,30]

# %%
a[3] #index 범위를 벗어남
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-f75b6be7d8e3> in <cell line: 1>()
# ----> 1 a[3]
#
# IndexError: list index out of range

# %%
print('{0} {1}.format(10,20))
# Out:
#   File "<ipython-input-5-8b7c5ae7adf7>", line 1
#     print('{0} {1}.format(10,20))
#                                  ^
# SyntaxError: EOL while scanning string literal

# %%
10/0 #0을 나눌 수 없다
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-6-e574edb36883> in <cell line: 1>()
# ----> 1 10/0
#
# ZeroDivisionError: division by zero

# %%
a='apple'
10/a #숫자는 문자를 나눌 수 없다
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-5ccfb8e9e364> in <cell line: 2>()
#       1 a='apple'
# ----> 2 10/a
#
# TypeError: unsupported operand type(s) for /: 'int' and 'str'

# %%
  def divide(a,b):
    return a/b

# %%
divide(10,0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-9-101aa8dc6e2a> in <cell line: 1>()
# ----> 1 divide(10,0)
#
# <ipython-input-8-f4dab5f4e365> in divide(a, b)
#       1 def divide(a,b):
# ----> 2   return a/b
#
# ZeroDivisionError: division by zero

# %%
# 수많은 error 를 대비해야함
# try-except문 
try:
  c=divide(5,0)
except:
  print('Exception is occured!!')
# Out:
# Exception is occured!!

# %%
try: 
  c = divide(10,0)
except ZeroDivisionError:
  print('두 번째 값은 0이 되면 안됩니다. ')
except TypeError:
  print('모든 인자는 숫자여야 합니다.')
except:
  print('알 수 없는 오류입니다.')
finally:
  print('감사합니다.')
# Out:
# 두 번째 값은 0이 되면 안됩니다.
# 감사합니다.
