# %% [markdown]
# # 확장, 침식 실험

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image_path='../data/apple.png'

image=cv2.imread(image_path,cv2.IMREAD_GRAYSCALE)

_, mask=cv2.threshold(image,230,255,cv2.THRESH_BINARY_INV) #230보다 큰 값은 255로 변환

image_list=np.hstack([
    image,
    mask
])

plt.imshow(image_list,'gray')
plt.show()

# %% [markdown]
# ## 확장,침식 실험 - 01

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image_path='../data/apple.png'

image=cv2.imread(image_path,cv2.IMREAD_GRAYSCALE)
_, mask=cv2.threshold(image,230,255,cv2.THRESH_BINARY_INV)
kernel=np.ones((3,3),np.uint8)

dilation= cv2.dilate(mask,kernel)


image_list=np.hstack([
    image,
    mask,
    dilation
])

plt.imshow(image_list,'gray')
plt.show()

# %% [markdown]
# # 확장,침식 실험 - 02

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image_path='../data/apple.png'

image=cv2.imread(image_path,cv2.IMREAD_GRAYSCALE)
_, mask=cv2.threshold(image,230,255,cv2.THRESH_BINARY_INV)
kernel=np.ones((3,3),np.uint8)

dilation= cv2.dilate(mask,kernel,iterations=2)


image_list=np.hstack([
    image,
    mask,
    dilation
])

plt.imshow(image_list,'gray')
plt.show()

# %% [markdown]
# # 확장,침식-03

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image_path='../data/apple.png'

image=cv2.imread(image_path,cv2.IMREAD_GRAYSCALE)
_, mask=cv2.threshold(image,230,255,cv2.THRESH_BINARY_INV)
kernel=np.ones((3,3),np.uint8)

dilation= cv2.dilate(mask,kernel,iterations=2)
erosion=cv2.erode(mask,kernel)

image_list=np.hstack([
    image,
    mask,
    dilation,
    erosion
])

plt.imshow(image_list,'gray')
plt.show()

# %% [markdown]
# # 침식,팽창-04

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
image_path='../data/apple.png'

image=cv2.imread(image_path,cv2.IMREAD_GRAYSCALE)
_, mask=cv2.threshold(image,230,255,cv2.THRESH_BINARY_INV)
kernel=np.ones((3,3),np.uint8)

dilation= cv2.dilate(mask,kernel,iterations=2)
erosion=cv2.erode(mask,kernel)

# 개폐 open close
opening=cv2.morphologyEx(mask,cv2.MORPH_OPEN,kernel)
closing=cv2.morphologyEx(mask,cv2.MORPH_CLOSE,kernel)

mg=cv2.morphologyEx(mask,cv2.MORPH_GRADIENT,kernel)
th=cv2.morphologyEx(mask,cv2.MORPH_TOPHAT,kernel)

image_list=np.hstack([
    image,
    mask,
    dilation,
    erosion,
    opening,
    closing 
])

image_list_01=np.hstack([
    mg,
    th
])

plt.imshow(image_list,'gray')
plt.show()

plt.imshow(image_list_01,'gray')
plt.show()
