# %%
# !pip install pandas
# !pip install matplotlib
# !pip install scipy
# Out:
# Requirement already satisfied: pandas in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.20.3 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (3.7.1)
# Requirement already satisfied: numpy>=1.20 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from matplotlib) (1.24.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from matplotlib) (5.12.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from matplotlib) (9.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from matplotlib) (1.0.7)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from matplotlib) (4.39.4)
# Requirement already satisfied: cycler>=0.10 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: zipp>=3.1.0 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Collecting scipy
#   Downloading scipy-1.10.1-cp38-cp38-macosx_12_0_arm64.whl (28.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.8/28.8 MB 10.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in /Users/iamseungman/opt/anaconda3/envs/MS/lib/python3.8/site-packages (from scipy) (1.24.3)
# Installing collected packages: scipy
# Successfully installed scipy-1.10.1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 데이터셋 불러오기
data= pd.read_csv('./data/BlackFriday.csv')

# User_ID별 구매 총 금액 계산
user_total_spent=data.groupby('User_ID')['Purchase'].sum()
print(user_total_spent)
# Out:
# User_ID
# 1000001     334093
# 1000002     810472
# 1000003     341635
# 1000004     206468
# 1000005     821001
#             ...
# 1006036    4116058
# 1006037    1119538
# 1006038      90034
# 1006039     590319
# 1006040    1653299
# Name: Purchase, Length: 5891, dtype: int64

# %%
plt.hist(user_total_spent,bins=50)
plt.title('Histogram of Total Purchase Amount by User')
plt.xlabel('Total Purchase Amount')
plt.ylabel('Frequency')
plt.show()

# %%
# 밀도 그래프 시각화
plt.figure()
user_total_spent.plot.kde()
plt.title('Density plot of Total Amount by User')
plt.xlabel('Total Purchase Amount')
plt.show()
