# %%
# !pip install azure_storage-queue==2.1.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 2.1 MB/s eta 0:00:00
# ...

# %%
from azure.storage.queue import QueueService, QueueMessageFormat

# %%
connect_str='' #연결문자열

queue_name='queue-myqueue'
queue_service=QueueService(connection_string=connect_str)

queue_service.create_queue(queue_name)
# Out:
# True

# %%
queue_service.encode_function= QueueMessageFormat.binary_base64encode
queue_service.decode_function= QueueMessageFormat.binary_base64decode

# %%
import base64
message='Hello World2'
print('Adding message: '+message)

message=base64.b64encode(message.encode('utf-8')) #유니코드를 base64방식으로 encode 
queue_service.put_message(queue_name,message)
# Out:
# Adding message: Hello World2

# %%
messages = queue_service.peek_messages(queue_name) #해당되는 메세지를 messages에 저장

for peeked_message in messages:
  message = base64.b64decode(peeked_message.content) #peek : 제일 처음에 들어간 message를 불러옴(queue에 남아있음)
  print('peeked message: '+ message.decode('utf-8'))
# Out:
# peeked message: Hello World

# %%
messages = queue_service.get_messages(queue_name) #get : 순서대로 꺼내옴(queue에 남아있지않음)

for msg in messages:
  message=base64.b64decode(msg.content)
  print('Got message : '+message.decode('utf-8'))
# Out:
# Got message : Hello World2

# %%
# Delete queue
queue_service.delete_queue(queue_name)
# Out:
# True
